# %% [markdown]
# <a href="https://colab.research.google.com/github/Otolomo1/simple-linear-regression-project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-64456ece-4809-4fd7-a0a9-dece12101e6f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64456ece-4809-4fd7-a0a9-dece12101e6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df =pd.read_csv("85334965-5736-457a-b8d4-a077e6872f84 (1).csv")
df.head()
# Out:
#      TV      Radio  Social_Media       Sales
# 0  16.0   6.566231      2.907983   54.732757
# 1  13.0   9.237765      2.409567   46.677897
# 2  41.0  15.886446      2.913410  150.177829
# 3  83.0  30.020028      6.922304  298.246340
# 4  15.0   8.437408      1.405998   56.594181

# %%
df.head()
# Out:
#      TV      Radio  Social_Media       Sales
# 0  16.0   6.566231      2.907983   54.732757
# 1  13.0   9.237765      2.409567   46.677897
# 2  41.0  15.886446      2.913410  150.177829
# 3  83.0  30.020028      6.922304  298.246340
# 4  15.0   8.437408      1.405998   56.594181

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Social_Media', 'Sales'], dtype='object')

# %%
print(df.corr(numeric_only=True))
# Out:
#                     TV     Radio  Social_Media     Sales
# TV            1.000000  0.869460      0.528168  0.999497
# Radio         0.869460  1.000000      0.607452  0.869105
# Social_Media  0.528168  0.607452      1.000000  0.528906
# Sales         0.999497  0.869105      0.528906  1.000000

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-74dc66ae-5cf8-4433-a523-7789ef3e5e66" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74dc66ae-5cf8-4433-a523-7789ef3e5e66">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("85334965-5736-457a-b8d4-a077e6872f84.csv")

# %%
df.head()
# Out:
#      TV      Radio  Social_Media       Sales
# 0  16.0   6.566231      2.907983   54.732757
# 1  13.0   9.237765      2.409567   46.677897
# 2  41.0  15.886446      2.913410  150.177829
# 3  83.0  30.020028      6.922304  298.246340
# 4  15.0   8.437408      1.405998   56.594181

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Social_Media', 'Sales'], dtype='object')

# %%
print(df.corr(numeric_only=True))
# Out:
#                     TV     Radio  Social_Media     Sales
# TV            1.000000  0.869460      0.528168  0.999497
# Radio         0.869460  1.000000      0.607452  0.869105
# Social_Media  0.528168  0.607452      1.000000  0.528906
# Sales         0.999497  0.869105      0.528906  1.000000

# %%
print(df[["TV", "Sales"]].isnull().sum())
# Out:
# TV       10
# Sales     6
# dtype: int64

# %%
df = df.dropna()

# %%
import statsmodels.api as sm

x = df["TV"]
y = df["Sales"]

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 4.517e+06
# Date:                Wed, 24 Jun 2026   Prob (F-statistic):               0.00
# Time:                        16:36:15   Log-Likelihood:                -11366.
# No. Observations:                4546   AIC:                         2.274e+04
# Df Residuals:                    4544   BIC:                         2.275e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1325      0.101     -1.317      0.188      -0.330       0.065
# ...

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 4.517e+06
# Date:                Wed, 24 Jun 2026   Prob (F-statistic):               0.00
# Time:                        16:38:00   Log-Likelihood:                -11366.
# No. Observations:                4546   AIC:                         2.274e+04
# Df Residuals:                    4544   BIC:                         2.275e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1325      0.101     -1.317      0.188      -0.330       0.065
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(df["TV"], df["Sales"])
plt.xlabel("TV Advertising")
plt.ylabel("Sales")
plt.title("TV Advertising vs Sales")
plt.show()

# %%
print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
import matplotlib.pyplot as plt

# %%
residuals = model.resid

plt.scatter(model.fittedvalues, residuals)
plt.axhline(y=0)
plt.xlabel("predicted Sales")
plt.ylabel("Residuals")
plt.title("Residual plot")
plt.show()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 4.517e+06
# Date:                Wed, 24 Jun 2026   Prob (F-statistic):               0.00
# Time:                        17:03:15   Log-Likelihood:                -11366.
# No. Observations:                4546   AIC:                         2.274e+04
# Df Residuals:                    4544   BIC:                         2.275e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1325      0.101     -1.317      0.188      -0.330       0.065
# ...

# %%
print(model.rsquared)
# Out:
# 0.998994984518024

# %%
print(model.params)
# Out:
# const   -0.132493
# TV       3.561514
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("")
